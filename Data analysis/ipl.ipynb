# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\ipl_matches_2008_2022.csv")
df.head(10)
# Out:
#    Unnamed: 0       id         city  match_date season match_number  \
# 0           0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1           1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2           2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3           3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4           4  1304116       Mumbai  2022-05-22   2022           70
# 5           5  1304115       Mumbai  2022-05-21   2022           69
# 6           6  1304114       Mumbai  2022-05-20   2022           68
# 7           7  1304113       Mumbai  2022-05-19   2022           67
# 8           8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9           9  1304111       Mumbai  2022-05-17   2022           65
#
#                          team1                        team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
type(df.loc[0,'match_date'])
# Out:
# str

# %%
df_ch = df.match_date.applymap(lambda x:x[::-1],na_action='ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_ch = df.match_date.applymap(lambda x:x[::-1],na_action='ignore')
#
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'applymap'

# %%
def format_date(x:str) -> str:
    x = x.split('-')
    return "-".join(x[::-1])

# %%
format_date('20-5-2022')
# Out:
# '2022-5-20'

# %%
df.match_date = df.match_date.apply(lambda x:'-'.join(x.split('-')[::-1]))

# %%
df.head(10)
# Out:
#    Unnamed: 0       id         city  match_date season match_number  \
# 0           0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1           1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2           2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3           3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4           4  1304116       Mumbai  2022-05-22   2022           70
# 5           5  1304115       Mumbai  2022-05-21   2022           69
# 6           6  1304114       Mumbai  2022-05-20   2022           68
# 7           7  1304113       Mumbai  2022-05-19   2022           67
# 8           8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9           9  1304111       Mumbai  2022-05-17   2022           65
#
#                          team1                        team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#         id         city  match_date season match_number  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          team1                        team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
a = "heoll"
"-".join(a)
# Out:
# 'h-e-o-l-l'

# %%
x = [12,120]
x[::-1]
# Out:
# [120, 12]

# %%
f = lambda x:'-'.join(x.split('-')[::-1])
f('20-05-2022')
# Out:
# '2022-05-20'

# %%
df.to_excel("C:\\Users\\ADMIN\\Desktop\\ipl_matches.xlsx")

# %%
df.match_date.dtype
# Out:
# dtype('O')

# %%
from mysql.connector import connect

# %%
db_connter = connect(host='localhost',user='root',password='root1234',database='IPL')

# %%
ipl_cursor = db_connter.cursor()

# %%
ipl_cursor.execute('drop table ipl_matches_2008_2022 ')
ipl_cursor.close()
# Out:
# True

# %%
res = ipl_cursor.fetchall()
print(res)
# Out:
# [('ipl_matches_2008_2022',)]

# %%
# Out:
#           id        city  match_date   season match_number  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            team1                        team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.to_sql('ipl_matches_2008_2022',db_connter,if_exists='replace',index=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15436\3884003618.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql('ipl_matches_2008_2022',db_connter,if_exists='replace',index=False)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\mysql\connector\cursor_cext.py:325, in CMySQLCursor.execute(self, operation, params, multi)
#     324         if psub.remaining != 0:
# ...

# %%
pip install pandas openpyxl
# Out:
# ...
#
# ...

# %%
import pymysql

# %%
connection = pymysql.connect(host="localhost",user='root',password = 'root1234',database='IPL')

# %%
df.to_sql('ipl_matches_2008_2022',connection,if_exists='append',index=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15436\3418089833.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql('ipl_matches_2008_2022',connection,if_exists='append',index=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\pymysql\cursors.py:151, in Cursor.execute(self, query, args)
#     149     pass
# --> 151 query = self.mogrify(query, args)
#     153 result = self._query(query)
#
# ...

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:root1234 :@localhost:3306/IPL')

# %%
df.to_sql('ipl_matches_2008_2022', engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df.to_sql('ipl_matches_2008_2022', engine, if_exists='replace', index=False)
#
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# ...

# %%
df
# Out:
#      Unnamed: 0       id        city  match_date   season match_number  \
# 0             0  1312200   Ahmedabad  2022-05-29     2022        Final
# 1             1  1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2             2  1312198     Kolkata  2022-05-25     2022   Eliminator
# 3             3  1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4             4  1304116      Mumbai  2022-05-22     2022           70
# ..          ...      ...         ...         ...      ...          ...
# 945         945   335986     Kolkata  2008-04-20  2007/08            4
# 946         946   335985      Mumbai  2008-04-20  2007/08            5
# 947         947   335984       Delhi  2008-04-19  2007/08            3
# 948         948   335983  Chandigarh  2008-04-19  2007/08            2
# 949         949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            team1                        team2  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# MySQL database connection details
host = 'localhost'
port = 3306
user = 'root'
password = 'root1234'
database = 'IPL'

# CSV file path
# csv_file = '/path/to/your/file.csv'

# MySQL table name
table_name = 'ipl_matches_2008_2022'

# Create the SQLAlchemy engine
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')

# Read CSV file into a pandas DataFrame
# df = pd.read_csv(csv_file)

# Insert data into the MySQL table
df.to_sql(table_name, engine, if_exists='replace', index=False)

# Close the database connection
engine.dispose()

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import mysql

# %%
df = pd.read_csv("C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\ipl_ball_by_ball_2008_2022.csv")
df.head()
# Out:
#         id  innings  overs  ball_number       batter          bowler  \
# 0  1312200        1      0            1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0            2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0            3   JC Buttler  Mohammed Shami
# 3  1312200        1      0            4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0            5  YBK Jaiswal  Mohammed Shami
#
#    non_striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    iswicket_delivery player_out dismisal_kind fielders_involved  \
# ...

# %%
df.shape
# Out:
# (225954, 17)

# %%
df.dtypes
# Out:
# id                    int64
# innings               int64
# overs                 int64
# ball_number           int64
# batter               object
# bowler               object
# non_striker          object
# extra_type           object
# batsman_run           int64
# extras_run            int64
# total_run             int64
# non_boundary          int64
# iswicket_delivery     int64
# player_out           object
# dismisal_kind        object
# fielders_involved    object
# batting_team         object
# dtype: object

# %%
host = 'localhost'
password = 'root1234'
port = 3306
user = 'user'
database = 'IPL'

# %%
table_name ='ipl_ball_by_ball_2008_2022'

# %%
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')

# %%
df.to_sql(table_name,engine,if_exists='replace',index=False)
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_sql(table_name,engine,if_exists='replace',index=False)
#       2 engine.dispose()
#
# File c:\users\admin\appdata\local\programs\python\python311\Lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
# ...

# %%
host = 'localhost'
user = 'root'
password = 'root1234'
port = 3306
database = 'IPL'
table = 'ipl_ball_by_ball_2008_2022'

engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
df.to_sql(table,engine,if_exists='replace',index=False)
engine.dispose()

# %%
import psycopg2

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Replace the placeholders with your actual database credentials
database = 'IPL_Database'
user = 'postgres'
password = 'illiyas'
host = 'localhost'
port = '5432'

# Create the connection string
connection_string = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}'

# Create the SQLAlchemy engine
engine = create_engine(connection_string)

# %%
table_name = 'ipl_matches_2008_2022'

# Insert the DataFrame into the PostgreSQL table
df.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 950

# %%
from sqlalchemy import create_engine

# %%
database = 'IPL_Database'
host = 'localhost'
user = 'postgres'
password = 'illiyas'
port = '5432'
table_name = 'ipl_matches_2008_2022'

engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')
df.to_sql(table_name,engine,if_exists='replace',index=False)
engine.dispose()

# %%
df.shape
# Out:
# (950, 18)
